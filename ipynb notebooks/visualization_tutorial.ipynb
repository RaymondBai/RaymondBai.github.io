# %%
# Importing necessary modules
import pandas as pd
import seaborn as sns

# %%
# Getting the Palmer Penguins data set
url = "https://raw.githubusercontent.com/PhilChodrow/PIC16B/master/datasets/palmer_penguins.csv"
penguins = pd.read_csv(url)

# %%
# Shorten the penguins' names
penguins["Species"] = penguins["Species"].str.split().str[0]

# %%
# Plotting interaction
cols = ['Culmen Length (mm)', 'Flipper Length (mm)', 'Body Mass (g)', "Species"]
plot = sns.pairplot(penguins[cols], hue = "Species", height = 3,
                    palette = {"Adelie":"#1f77b5",
                               "Chinstrap":"#2ba02b",
                               "Gentoo":"#e05c54"}
                   )
plot.savefig("visualization.png")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /var/folders/b8/wwntgvwx5c5cs44nrv14s0r80000gn/T/ipykernel_69825/2134207245.py in <module>
#       6                                "Gentoo":"#e05c54"}
#       7                    )
# ----> 8 plot.savefig("~/Desktop/PIC16B/RaymondBai.github.io/images/visualization.png")
#
# ~/opt/anaconda3/envs/PIC16B/lib/python3.7/site-packages/seaborn/axisgrid.py in savefig(self, *args, **kwargs)
#      63         kwargs = kwargs.copy()
#      64         kwargs.setdefault("bbox_inches", "tight")
# ---> 65         self.figure.savefig(*args, **kwargs)
#      66
#      67
#
# ~/opt/anaconda3/envs/PIC16B/lib/python3.7/site-packages/matplotlib/figure.py in savefig(self, fname, transparent, **kwargs)
#    3017                         ax.patch._cm_set(facecolor='none', edgecolor='none'))
#    3018
# -> 3019             self.canvas.print_figure(fname, **kwargs)
#    3020
#    3021     def ginput(self, n=1, timeout=30, show_clicks=True,
#
# ~/opt/anaconda3/envs/PIC16B/lib/python3.7/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2323                         orientation=orientation,
#    2324                         bbox_inches_restore=_bbox_inches_restore,
# -> 2325                         **kwargs)
#    2326             finally:
#    2327                 if bbox_inches and restore_bbox:
#
# ~/opt/anaconda3/envs/PIC16B/lib/python3.7/site-packages/matplotlib/backend_bases.py in wrapper(*args, **kwargs)
#    1646             kwargs.pop(arg)
#    1647
# -> 1648         return func(*args, **kwargs)
#    1649
#    1650     return wrapper
#
# ~/opt/anaconda3/envs/PIC16B/lib/python3.7/site-packages/matplotlib/_api/deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     410                          else deprecation_addendum,
#     411                 **kwargs)
# --> 412         return func(*inner_args, **inner_kwargs)
#     413
#     414     DECORATORS[wrapper] = decorator
#
# ~/opt/anaconda3/envs/PIC16B/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py in print_png(self, filename_or_obj, metadata, pil_kwargs, *args)
#     541         mpl.image.imsave(
#     542             filename_or_obj, self.buffer_rgba(), format="png", origin="upper",
# --> 543             dpi=self.figure.dpi, metadata=metadata, pil_kwargs=pil_kwargs)
#     544
#     545     def print_to_buffer(self):
#
# ~/opt/anaconda3/envs/PIC16B/lib/python3.7/site-packages/matplotlib/image.py in imsave(fname, arr, vmin, vmax, cmap, format, origin, dpi, metadata, pil_kwargs)
#    1673         pil_kwargs.setdefault("format", format)
#    1674         pil_kwargs.setdefault("dpi", (dpi, dpi))
# -> 1675         image.save(fname, **pil_kwargs)
#    1676
#    1677
#
# ~/opt/anaconda3/envs/PIC16B/lib/python3.7/site-packages/PIL/Image.py in save(self, fp, format, **params)
#    2207                 fp = builtins.open(filename, "r+b")
#    2208             else:
# -> 2209                 fp = builtins.open(filename, "w+b")
#    2210
#    2211         try:
#
# FileNotFoundError: [Errno 2] No such file or directory: '~/Desktop/PIC16B/RaymondBai.github.io/images/visualization.png'
